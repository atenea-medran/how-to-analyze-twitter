# %% [markdown]
# # Pasar datos en formato json a txt

# %% [markdown]
# Comenzamos importando las librerías y estableciendo las opciones de pandas que queremos.

# %%
import json
import pandas as pd
from datetime import datetime as dt
import numpy as np
from IPython.display import Image

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %% [markdown]
# Guardamos en una variable el nombre de nuestro hashtag o palabra clave.

# %%
hashtag = 'felizmiercoles'

# %% [markdown]
# El json obtenido con twarc2 tiene múltiples items, uno por cada 100 tweets.

# %%
tweets_data = []

tweets_file = open(f'{hashtag}.jsonl', encoding = 'utf-8')

for line in tweets_file:
    tweet = json.loads(line)
    tweets_data.append(tweet)

tweets_file.close()

print('Numero de items: ',len(tweets_data))
# Out:
# Numero de items:  104

# %% [markdown]
# ### Ejemplo de estructura de json

# %% [markdown]
# En este ejemplo solo he cogido un tweet del hashtag #estoesunaprueba123 para facilitar la visualización. Si tuvieramos más de 100 tweets el diccionario que marca el primer corchete contendría una lista de items.

# %%
Image(url="Images/json_tree.png", width=600,height=600)
# Out:
# <img src="Images/json_tree.png" width="600" height="600"/>

# %% [markdown]
# ### Extracción de los datos

# %% [markdown]
# Loopeamos en la lista de items del json para que de cada item (100 tweets) podamos acceder a los datos de los tweets. Luego accedemos a la lista que está dentro de `item['data']` y loopeamos de nuevo para coger cada pieza de información de todos los tweets e introducirla en una variable. Por último este loop va a unir toda la información en `list_tweets_flattered`, que es una lista vacía que vamos a llenar con otras listas, una por tweet. A cada pieza de información se accede con una combinación de diccionarios y listas que tenemos que ir desgranando.

# %%
list_tweets_flattered = []
i = 0
for item in tweets_data:
    list_tweets = item['data']
    for tweet in list_tweets:
        text = tweet['text']
        if 'account is temporarily unavailable because it violates the Twitter Media Policy. Learn more.' not in text:
            if 'referenced_tweets' in tweet:
                type = tweet['referenced_tweets'][0]['type']
                if type == 'quoted' or type == 'tweet' or type == 'replied_to':
                    #Aqui se puede añadir user quoted e id quoted
                    user_retweeted = 'None'
                    id_tweet_retweeted = 'None'
                elif type == 'retweeted' and 'mentions' in tweet['entities']:
                    user_retweeted = tweet['entities']['mentions'][0]['username']
                    id_tweet_retweeted = tweet['referenced_tweets'][0]['id']

            elif 'referenced_tweets' not in tweet:
                type = 'tweet'
                user_retweeted = 'None'
                id_tweet_retweeted = 'None'

            id_user = tweet['author_id']
            date = tweet['created_at']
            source = tweet['source']
            reply_settings = tweet['reply_settings']
            id_tweet = tweet['id']
            retweet_count = tweet['public_metrics']['retweet_count']
            reply_count = tweet['public_metrics']['reply_count']
            like_count = tweet['public_metrics']['like_count']
            quote_count = tweet['public_metrics']['quote_count']
            lang = tweet['lang']
        else:
            i += 1

        list_tweets_flattered.append([type,id_tweet_retweeted,user_retweeted,id_user,date,source,text,reply_settings,id_tweet,retweet_count,
                                        reply_count,like_count,quote_count,lang])

# %% [markdown]
# Esa lista de listas la convertimos en dataframe.

# %%
tweets_df = pd.DataFrame(list_tweets_flattered,columns=['relation','id tweet retweeted','user retweeted','id author','date','app','text','reply settings',
'id tweet','retweet count','reply count','like count','quote count','lang'])
tweets_df.head(2)
# Out:
#     relation   id tweet retweeted user retweeted            id author  \
# 0  retweeted  1593000961420627969    yosoysexmex           2384230938
# 1  retweeted  1593079107725963265     JorgitoLRA  1041735251633102848
#
#                        date                  app  \
# 0  2022-11-17T17:41:26.000Z   Twitter for iPhone
# 1  2022-11-17T17:40:20.000Z  Twitter for Android
#
#                                                                                                                                              text  \
# 0   RT @yosoysexmex: Godínez no es tan estúpido después de todo.\nlogró hipnotizar a su jefa para realizar sus deseos más perversos y probar esa…
# 1  RT @JorgitoLRA: «Eso no se entiende ¿Quién le dio la orden a usted de nombrar un embajador?», dijo Cabello.\n\nCabello al presidente uruguayo…
#
#   reply settings             id tweet  retweet count  reply count  like count  \
# 0       everyone  1593298280867323904            178            0           0
# 1       everyone  1593298003141574660             23            0           0
#
#    quote count lang
# 0            0   es
# 1            0   es

# %% [markdown]
# Hacemos lo mismo con la información de los usuarios.

# %%
list_users_flattered = []

for item in tweets_data:
    list_users = item['includes']['users']
    for user in list_users:
        if 'location' in user:
            location = user['location']
        else:
            location = 'None'
        username = user['username']
        verified = user['verified']
        name = user['name']
        id_user = user['id']
        profile_image_url = user['profile_image_url']
        followers_count = user['public_metrics']['followers_count']
        following_count = user['public_metrics']['following_count']
        tweet_count = user['public_metrics']['tweet_count']
        listed_count = user['public_metrics']['listed_count']
        bio = user['description']
        created_at = user['created_at']
        if 'url' in user:
            url_list = user['entities']['url']['urls']
            url_end = []
            for url_unique in url_list:
                if 'expanded url' in url_unique:
                    url_end.append(url_unique['expanded_url'])
                elif 'expanded url' not in url_unique:
                    url_end.append(url_unique['url'])
        else:
            url_end = 'None'

        if 'entities' in user:
            if 'description' in user['entities']:
                if 'urls' in user['entities']['description']:
                    url_list2 = user['entities']['description']['urls']
                    url_end2 = []
                    for url_unique2 in url_list2:
                        url_end2.append(url_unique2['expanded_url'])
                else:
                    url_end2 = 'None'
        else:
            url_end2 = 'None'
        list_users_flattered.append([location,username,verified,name,id_user,profile_image_url,
        followers_count,following_count,tweet_count,listed_count,bio,created_at,url_end,url_end2])

# %%
users_df = pd.DataFrame(list_users_flattered,columns=['location','author','verified','name',
'id author','profile image url','followers','following','tweets','listed',
'description','created at','author url','description urls'])
users_df = users_df.drop_duplicates(subset='id author')

# %% [markdown]
# Añadimos la información de los usuarios haciendo un merge.

# %%
merged = tweets_df.merge(users_df,how='left',on='id author')
merged.head(2)
# Out:
#     relation   id tweet retweeted user retweeted            id author  \
# 0  retweeted  1593000961420627969    yosoysexmex           2384230938
# 1  retweeted  1593079107725963265     JorgitoLRA  1041735251633102848
#
#                        date                  app  \
# 0  2022-11-17T17:41:26.000Z   Twitter for iPhone
# 1  2022-11-17T17:40:20.000Z  Twitter for Android
#
#                                                                                                                                              text  \
# 0   RT @yosoysexmex: Godínez no es tan estúpido después de todo.\nlogró hipnotizar a su jefa para realizar sus deseos más perversos y probar esa…
# 1  RT @JorgitoLRA: «Eso no se entiende ¿Quién le dio la orden a usted de nombrar un embajador?», dijo Cabello.\n\nCabello al presidente uruguayo…
#
#   reply settings             id tweet  retweet count  reply count  like count  \
# 0       everyone  1593298280867323904            178            0           0
# 1       everyone  1593298003141574660             23            0           0
#
#    quote count lang           location           author  verified  \
# 0            0   es             México       Biscositos     False
# 1            0   es  Valera, Venezuela  JoseRafaelbenc2     False
#
#                                                 name  \
# 0                                         Biscositos
# 1  Topógrafo. JOSÉ ꃳEꋊꉔOMO Comunicador Clap Trujillo
#
#                                                               profile image url  \
# 0   https://pbs.twimg.com/profile_images/443511399537315840/134wPIe8_normal.png
# 1  https://pbs.twimg.com/profile_images/1396299556439171072/jQWWOH20_normal.jpg
#
#    followers  following  tweets  listed  \
# 0        700       2092   40303       6
# 1       5717       5705  565271       3
#
#                                                                                                                                                 description  \
# 0  Somos Pareja, en busca de diversión, compartir fotos y experiencias etc.....si se da otra cosa porque no?....Cuenta creada y administrada por mi (Mujer)
# 1                                  ✊anti imperialista✊magallanero✊y radicalmente✊chavista, Leales Siempre,Traidores Nunca.🇻🇪🇹🇷🇷🇺🇨🇳 #ComunicadorClapTrujillo
#
#                  created at author url description urls
# 0  2014-03-11T21:42:44.000Z       None             None
# 1  2018-09-17T17:06:53.000Z       None             None

# %% [markdown]
# Limpiamos las columnas de fechas.

# %%
merged['date'] = merged['date'].apply(lambda x:str(x))
merged['date'] = merged['date'].str.replace('T',' ',regex=True)
merged['date'] = merged['date'].str.replace('Z','',regex=True)
merged['date'] = merged['date'].str.replace('000','',regex=True)
merged['date'] = merged['date'].str.replace('.','',regex=True)

# %%
merged['created at'] = merged['created at'].apply(lambda x:str(x))
merged['created at'] = merged['created at'].str.replace('T',' ',regex=True)
merged['created at'] = merged['created at'].str.replace('Z','',regex=True)
merged['created at'] = merged['created at'].str.replace('000','',regex=True)
merged['created at'] = merged['created at'].str.replace('.','',regex=True)

# %% [markdown]
# Transformamos las 2 columnas de fechas de nuevo a objeto datetime (fecha y tiempo) para luego poder ordenar el dataframe cronológicamente. Si queda en formato `string` Python no podría saber cuál es mayor o menor.

# %%
merged['date'] = merged['date'].apply(lambda x:dt.strptime(x, '%Y-%m-%d %H:%M:%S'))
merged['created at'] = merged['created at'].apply(lambda x:dt.strptime(x, '%Y-%m-%d %H:%M:%S'))

# %% [markdown]
# Quitamos los saltos de línea (\n) de las columnas de textos largos como la texto del tweet o la de la descripción.

# %%
merged['text'] = merged['text'].str.replace('\n',' ')
merged['description'] = merged['description'].str.replace('\n',' ')

# %% [markdown]
# Ordenamos las columnas a nuestro gusto.

# %%
merged = merged[['id tweet','date','text','lang','app','author','id author','name','description','location','created at','author url','description urls',
'profile image url','followers','following','tweets','relation','user retweeted','id tweet retweeted']]
merged.head(2)
# Out:
#               id tweet                date  \
# 0  1593298280867323904 2022-11-17 17:41:26
# 1  1593298003141574660 2022-11-17 17:40:20
#
#                                                                                                                                            text  \
# 0  RT @yosoysexmex: Godínez no es tan estúpido después de todo. logró hipnotizar a su jefa para realizar sus deseos más perversos y probar esa…
# 1  RT @JorgitoLRA: «Eso no se entiende ¿Quién le dio la orden a usted de nombrar un embajador?», dijo Cabello.  Cabello al presidente uruguayo…
#
#   lang                  app           author            id author  \
# 0   es   Twitter for iPhone       Biscositos           2384230938
# 1   es  Twitter for Android  JoseRafaelbenc2  1041735251633102848
#
#                                                 name  \
# 0                                         Biscositos
# 1  Topógrafo. JOSÉ ꃳEꋊꉔOMO Comunicador Clap Trujillo
#
#                                                                                                                                                 description  \
# 0  Somos Pareja, en busca de diversión, compartir fotos y experiencias etc.....si se da otra cosa porque no?....Cuenta creada y administrada por mi (Mujer)
# 1                                  ✊anti imperialista✊magallanero✊y radicalmente✊chavista, Leales Siempre,Traidores Nunca.🇻🇪🇹🇷🇷🇺🇨🇳 #ComunicadorClapTrujillo
#
#             location          created at author url description urls  \
# 0             México 2014-03-11 21:42:44       None             None
# 1  Valera, Venezuela 2018-09-17 17:06:53       None             None
#
#                                                               profile image url  \
# 0   https://pbs.twimg.com/profile_images/443511399537315840/134wPIe8_normal.png
# 1  https://pbs.twimg.com/profile_images/1396299556439171072/jQWWOH20_normal.jpg
#
#    followers  following  tweets   relation user retweeted   id tweet retweeted
# 0        700       2092   40303  retweeted    yosoysexmex  1593000961420627969
# 1       5717       5705  565271  retweeted     JorgitoLRA  1593079107725963265

# %% [markdown]
# Twitter no almacena todo el texto del tweet en el caso de los retweets, por lo que tenemos que acceder a estos en el apartado de `[includes][tweets]`. De paso podemos extraer los hashtags, las claves identificativas de lo audiovisual (fotos, gifs, videos) y las urls del tweet (hay otras urls en la descripción o en el campo de url del perfil, no debemos confundirlas).

# %%
list_original_tweets_flattened = []

i = 0

for item in tweets_data:
    j = 0
    list_original_tweets = item['includes']['tweets']
    for tweet in list_original_tweets:
        id2 = tweet['id']
        if 'referenced_tweets' in tweet and tweet['referenced_tweets'][0]['type'] == 'retweeted':
            id_tweet_retweeted = tweet['referenced_tweets'][0]['id']
        else:
            id_tweet_retweeted = 'None'
        text2 = tweet['text']
        if 'entities' in tweet:
            if 'hashtags' in tweet['entities']:
                hashtags = tweet['entities']['hashtags']
                hashtag_list = []
                for ht in hashtags:
                    hashtag_list.append(ht['tag'])
            elif 'hashtags' not in tweet['entities']:
                hashtag_list = 'None'
            if 'urls' in tweet['entities']:
                urls = tweet['entities']['urls']
                url_list = []
                media_list = []
                for url in urls:
                    url_list.append(url['expanded_url'])
                    if 'media_key' in url:
                        media_keys = url['media_key']
                        media_list.append(url['media_key'])
            elif 'urls' not in tweet['entities']:
                url_list = 'None'
                media_list = []  

        list_original_tweets_flattened.append([id2,id_tweet_retweeted,text2,hashtag_list,url_list,media_list])

# %% [markdown]
# También lo pasamos a dataframe y de la columna 'whole text' quitamos los saltos de linea (\n).

# %%
original_tweets_df = pd.DataFrame(list_original_tweets_flattened,columns=['id tweet','id tweet retweeted','whole text','tweet hashtags','tweet urls','media keys'])
original_tweets_df['whole text'] = original_tweets_df['whole text'].str.replace('\n',' ')
original_tweets_df.head(2)
# Out:
#               id tweet   id tweet retweeted  \
# 0  1593298280867323904  1593000961420627969
# 1  1593000961420627969                 None
#
#                                                                                                                                                                                                                                                                                                          whole text  \
# 0                                                                                                                                                                      RT @yosoysexmex: Godínez no es tan estúpido después de todo. logró hipnotizar a su jefa para realizar sus deseos más perversos y probar esa…
# 1  Godínez no es tan estúpido después de todo. logró hipnotizar a su jefa para realizar sus deseos más perversos y probar esas enormes y carnosas tetas!  "Hipnotizada" @Karicachonda7 y #RickyMartinez   Link: https://t.co/qrqXqS1bbP  https://t.co/8tX8LnUYU0   #SEXMEX  #FelizMiercoles https://t.co/M0yiyRopuk
#
#                             tweet hashtags  \
# 0                                     None
# 1  [RickyMartinez, SEXMEX, FelizMiercoles]
#
#                                                                                                                                                tweet urls  \
# 0                                                                                                                                                    None
# 1  [https://sexmex.xxx/tour/updates/Mesmerized-Kari-Cachonda.html, http://SEXMEX.XXX, https://twitter.com/yosoysexmex/status/1593000961420627969/video/1]
#
#                 media keys
# 0                       []
# 1  [7_1592923712021532672]

# %% [markdown]
# De este dataframe solo nos interesan los tweets que no son retweets porque son los que contendrán el texto completo. Hay tweets que estarán en los 2 items del json, así que limpiamos los duplicados. También quitamos la columna 'id tweet retweeted' porque aquí no nos interesa.

# %%
original_tweets_df_normal = original_tweets_df[original_tweets_df['id tweet retweeted'] == 'None']
original_tweets_df_normal = original_tweets_df_normal.drop_duplicates(subset='id tweet')
original_tweets_df_normal = original_tweets_df_normal.drop('id tweet retweeted',axis=1)
original_tweets_df_normal
# Out:
#                   id tweet  \
# 1      1593000961420627969
# 3      1593079107725963265
# 5      1593079747990663173
# 7      1593061361151524867
# 9      1593046127452250113
# ...                    ...
# 16862  1592936593501093888
# 16866  1592936577311080449
# 16867  1592918905055739905
# 16879  1592936454711296002
# 16884  1592936363984584704
#
#                                                                                                                                                                                                                                                                                                              whole text  \
# 1      Godínez no es tan estúpido después de todo. logró hipnotizar a su jefa para realizar sus deseos más perversos y probar esas enormes y carnosas tetas!  "Hipnotizada" @Karicachonda7 y #RickyMartinez   Link: https://t.co/qrqXqS1bbP  https://t.co/8tX8LnUYU0   #SEXMEX  #FelizMiercoles https://t.co/M0yiyRopuk
# 3                            «Eso no se entiende ¿Quién le dio la orden a usted de nombrar un embajador?», dijo Cabello.  Cabello al presidente uruguayo: no hace falta un embajador de su país  @dcabellor   #PatriaUnidaParaTriunfar #16Noviembre #FelizMiercoles #Qatar2022 #DebatirYRenovar https://t.co/yynsCEatC1
# 5                                                                                                                                                                                                             #PatriaUnidaParaTriunfar #16Noviembre #FelizMiercoles #Qatar2022 #DebatirYRenovar https://t.co/ybNSl0R5d9
# 7                                                             Dasha premio a un lanchero por salvarle la vida. le entrego las nalgas allí mismo en la playa!  @SexxxyDasha y @lucyandominus   EL MEJOR PORNO EN ESPAÑOL SOLO EN https://t.co/8tX8LnDo2s   #SEXMEX #YosoySexmex  #FelizMiercoles https://t.co/hGuRHC9mE8
# 9                                                                                                             Necesito un Gojo kun en mi vida 😄 #FelizMiercoles #FelizMiercolesATodos #cosplay #streamer #marinkitagawacosplay #marinkitagawa #marincosplay #sonobisquedollwakoiwosuru #shizuku https://t.co/FOr2UbWvrK
# ...                                                                                                                                                                                                                                                                                                                 ...
# 16862                                                                                                                                                                                                    #DelfinaTenPercent el # que lo dice todo y los chairos no entienden?   #FelizMiércoles https://t.co/lJMWwfaNt6
# 16866                                                                                                                                                                                                                                @Azu31480995Azu Linda tarde para ti Azu!!  #FelizMiercoles https://t.co/jsKckwqQkw
# 16867                                                                                                                                                                                                                                                          @kosmos69 Feliz miércoles Kosmos https://t.co/SwkgmvBVWK
# 16879                                    #Capricornio ♑ recuerda que cualquier cosa que hayas decidido hacer, hazla con todas tus fuerzas. Lo que nos hace feliz es perseguir nuestros sueños. 😎 #Horóscopodia #SignosdelZodíaco #Predicciones #FelizMiércoles.  en 👀👇👇 https://t.co/SNV10zB2U9 https://t.co/MceGUW6ia9
# 16884                                                                                                                                                                                                     #Pensamientos ¿Impaciente yo?... 💆‍♀️🧘‍♀️ #Tú #FelizMIércoles https://t.co/ZRkA4h10nu https://t.co/gsksoSj4fr
#
#                                                                                                                                          tweet hashtags  \
# 1                                                                                                               [RickyMartinez, SEXMEX, FelizMiercoles]
# 3                                                                    [PatriaUnidaParaTriunfar, 16Noviembre, FelizMiercoles, Qatar2022, DebatirYRenovar]
# 5                                                                    [PatriaUnidaParaTriunfar, 16Noviembre, FelizMiercoles, Qatar2022, DebatirYRenovar]
# 7                                                                                                                 [SEXMEX, YosoySexmex, FelizMiercoles]
# 9      [FelizMiercoles, FelizMiercolesATodos, cosplay, streamer, marinkitagawacosplay, marinkitagawa, marincosplay, sonobisquedollwakoiwosuru, shizuku]
# ...                                                                                                                                                 ...
# 16862                                                                                                               [DelfinaTenPercent, FelizMiércoles]
# 16866                                                                                                                                  [FelizMiercoles]
# 16867                                                                                                                                              None
# 16879                                                                       [Capricornio, Horóscopodia, SignosdelZodíaco, Predicciones, FelizMiércoles]
# 16884                                                                                                                [Pensamientos, Tú, FelizMIércoles]
#
#                                                                                                                                                    tweet urls  \
# 1      [https://sexmex.xxx/tour/updates/Mesmerized-Kari-Cachonda.html, http://SEXMEX.XXX, https://twitter.com/yosoysexmex/status/1593000961420627969/video/1]
# 3                                                                                         [https://twitter.com/JorgitoLRA/status/1593079107725963265/photo/1]
# 5                                                                                         [https://twitter.com/JorgitoLRA/status/1593079747990663173/photo/1]
# 7                                                                     [http://SEXMEX.XXX, https://twitter.com/yosoysexmex/status/1593061361151524867/video/1]
# 9                                                                                           [https://twitter.com/maryanmg/status/1593046127452250113/photo/1]
# ...                                                                                                                                                       ...
# 16862                                                                                 [https://twitter.com/ordenesdelamor/status/1592936593501093888/photo/1]
# 16866                                                                                       [https://twitter.com/kosmos69/status/1592936577311080449/photo/1]
# 16867                                                                                 [https://twitter.com/Azu31480995Azu/status/1592918905055739905/photo/1]
# 16879                           [https://elhoroscopodelzodiaco.com/horoscopo-diario/, https://twitter.com/elhoroscopodel1/status/1592936454711296002/photo/1]
# 16884                                 [https://www.pensamientos.com.mx/impaciente_yo.htm, https://twitter.com/clubplaneta/status/1592936363984584704/photo/1]
#
#                      media keys
# 1       [7_1592923712021532672]
# 3       [3_1593079105213325313]
# 5       [3_1593079745691910148]
# 7       [7_1593021183628304385]
# 9       [3_1593046123933241345]
# ...                         ...
# 16862  [16_1592936581614080000]
# 16866   [3_1592936572395061253]
# 16867   [3_1592918901695946757]
# 16879   [3_1592936450974257154]
# 16884   [3_1592936346397691904]
#
# [3426 rows x 5 columns]

# %% [markdown]
# Ahora cogemos solo los tweets originales de nuestro dataframe original y le hacemos un merge para añadir los datos. Lo hacemos así porque los tweets originales se relacionan por la columna 'id tweet' y los retweets por la columna 'id tweet retweeted'. Hacemos el merge y ya tenemos 40 tweets con los hashtags, las urls y las media keys. Quitamos la columna 'id tweet retweeted' porque aquí no no interesa.

# %%
merged_normal = merged[merged['relation'] != 'retweeted']
merged_normal = merged_normal.merge(original_tweets_df_normal,on='id tweet',how='left')
merged_normal = merged_normal.drop('id tweet retweeted',axis=1)
print(len(merged_normal))
merged_normal.head(5)
# Out:
# 1490
#               id tweet                date  \
# 0  1593295270544134144 2022-11-17 17:29:29
# 1  1593295160485502986 2022-11-17 17:29:02
# 2  1593286886402973696 2022-11-17 16:56:10
# 3  1593285182018265091 2022-11-17 16:49:23
# 4  1593282790702911488 2022-11-17 16:39:53
#
#                                                                                                                                                                                                                                                     text  \
# 0                                                                          #Virgo en el Amor – Miércoles, 16 de noviembre de 2022 #Horóscopo #Amor #Amistad #Zodiaco #Horoscopo2022 #Love https://t.co/KgwdSVF4hx #felizmiércoles #prediccionesamorvirgo
# 1                                                                                                                                                                            Qué profesión es más infiel ?  #MiercolesDeGanarSeguidores  #FelizMiercoles
# 2  Y tú novia se ve así cuando se baña? 💦🦊❤️‍🔥👀 Seguro que no… Mejor sígueme a mi y te suscribes de paso que jugamos sin que ella sepa😉  https://t.co/EgMvEBNLvN  #FelizMiercoles #onlyfansgirl #Espana #gothgirl #nudienovember https://t.co/vyEUVy1m85
# 3                                                                                                             Buenas Tardes bellezas 😘😃! Send mates y buena energía 🧉💯! Excelente día para todos ❤️! #BuenJueves #FelizMiercoles https://t.co/w4cw68SIjk
# 4                                                                                                                                                             Hola =)  #onlyfans #topguy #FelizCumpleanosRuPaul  #FelizMiercoles https://t.co/7VqkS2v8u8
#
#   lang                  app           author            id author  \
# 0   es    Revive Social App  _Horoscopo_Amor   950141474208919554
# 1   es  Twitter for Android   Cata_la_rola23  1590149090482036742
# 2   es   Twitter for iPhone    ScarlettDark_  1574829744725659652
# 3   es  Twitter for Android        mchyssNew  1419376703781195777
# 4   es      Twitter Web App       SantoPaco1  1593280814871191553
#
#                name  \
# 0    Horóscopo Amor
# 1  Catalina Andrade
# 2          Scarlett
# 3           Mechy ☘
# 4        Santo Paco
#
#                                                                                                                                                       description  \
# 0  ❤️ ❤️ Predicción diaria de los #horóscopos del #AMOR para cada uno de los signos del Zodiaco. Gratis. ✨✨  #Amistad #Parejas #Amor #Sexo #Sexualidad #Love ❤️❤️
# 1                                                                                                     Rola, futbolera, mal pensada, opino de lo que no sé. 🦁🛫🏟️⚽😈
# 2                                                                       🥀a real devil in a fake angels world. 🔯❤️‍🔥🔞 🥀. La gótica que te gusta más que tu novia.🦊
# 3         Entrerriana en BsAs 📌 No prometo nada wow..siempre buena onda, música, pavadas #MartesCantado #TeRegaloUnaCancion Mi otra cuenta es @mchyss seguime ahí
# 4
#
#                          location          created at  \
# 0                       Estrellas 2018-01-07 23:05:55
# 1                            None 2022-11-09 01:07:48
# 2                        Infierno 2022-09-27 18:34:14
# 3  Ciudad Autónoma de Buenos Aire 2021-07-25 19:19:34
# 4                            None 2022-11-17 16:32:11
#
#                   author url description urls  \
# 0  [https://t.co/hHWxgGBknR]             None
# 1                       None             None
# 2  [https://t.co/M2gfD1VjzR]             None
# 3  [https://t.co/9hKBVFVGNY]             None
# 4                       None             None
#
#                                                               profile image url  \
# 0   https://pbs.twimg.com/profile_images/950504674444103683/s8l_MYiX_normal.jpg
# 1  https://pbs.twimg.com/profile_images/1591310513132142592/fy6kmIHZ_normal.jpg
# 2  https://pbs.twimg.com/profile_images/1587762141657964545/8ILeEECB_normal.jpg
# 3  https://pbs.twimg.com/profile_images/1589443730213376001/pATau7pm_normal.jpg
# 4  https://pbs.twimg.com/profile_images/1593281079707844608/3vUEJzvf_normal.jpg
#
#    followers  following  tweets relation user retweeted  \
# 0        106         84   28147    tweet           None
# 1        340        206     200    tweet           None
# 2         26          8      17    tweet           None
# 3      30237        992   32760    tweet           None
# 4          0          9       2    tweet           None
#
#                                                                                                                                                                                                                                               whole text  \
# 0                                                                          #Virgo en el Amor – Miércoles, 16 de noviembre de 2022 #Horóscopo #Amor #Amistad #Zodiaco #Horoscopo2022 #Love https://t.co/KgwdSVF4hx #felizmiércoles #prediccionesamorvirgo
# 1                                                                                                                                                                            Qué profesión es más infiel ?  #MiercolesDeGanarSeguidores  #FelizMiercoles
# 2  Y tú novia se ve así cuando se baña? 💦🦊❤️‍🔥👀 Seguro que no… Mejor sígueme a mi y te suscribes de paso que jugamos sin que ella sepa😉  https://t.co/EgMvEBNLvN  #FelizMiercoles #onlyfansgirl #Espana #gothgirl #nudienovember https://t.co/vyEUVy1m85
# 3                                                                                                             Buenas Tardes bellezas 😘😃! Send mates y buena energía 🧉💯! Excelente día para todos ❤️! #BuenJueves #FelizMiercoles https://t.co/w4cw68SIjk
# 4                                                                                                                                                             Hola =)  #onlyfans #topguy #FelizCumpleanosRuPaul  #FelizMiercoles https://t.co/7VqkS2v8u8
#
#                                                                                            tweet hashtags  \
# 0  [Virgo, Horóscopo, Amor, Amistad, Zodiaco, Horoscopo2022, Love, felizmiércoles, prediccionesamorvirgo]
# 1                                                            [MiercolesDeGanarSeguidores, FelizMiercoles]
# 2                                         [FelizMiercoles, onlyfansgirl, Espana, gothgirl, nudienovember]
# 3                                                                            [BuenJueves, FelizMiercoles]
# 4                                               [onlyfans, topguy, FelizCumpleanosRuPaul, FelizMiercoles]
#
#                                                                                                                               tweet urls  \
# 0  [https://horoscopo-amor.com/virgo-miercoles-16-noviembre-2022/?utm_source=ReviveOldPost&utm_medium=social&utm_campaign=ReviveOldPost]
# 1                                                                                                                                   None
# 2                               [http://onlyfans.com/scarlettdark, https://twitter.com/ScarlettDark_/status/1593286886402973696/video/1]
# 3                                                                     [https://twitter.com/mchyssNew/status/1593285182018265091/photo/1]
# 4                                                                    [https://twitter.com/SantoPaco1/status/1593282790702911488/photo/1]
#
#                 media keys
# 0                       []
# 1                       []
# 2  [7_1593286860687773696]
# 3  [3_1593285178335674370]
# 4  [3_1593282391728132101]

# %% [markdown]
# Como dijimos antes, cada tipo de tweet se relaciona con una clave diferente (Ej: 'id tweet'), así que para facilitarlo vamos a cambiarle el nombre para que no me duplique columnas y empiece a añadir _x, _y, etc.

# %%
original_tweets_df_normal = original_tweets_df_normal.rename(columns={'id tweet':'id to merge'})

# %% [markdown]
# Ahora cogemos solo los retweets de nuestro dataframe, también le cambiamos el nombre de la columna a relacionar y hacemos el merge. Por último actualizamos el texto asignándole "RT @ {usuario}: " y el texto del tweet original. Como dijimos, Twitter no almacena los textos completos de los retweets para ahorrar espacio.

# %%
merged_rt = merged[merged['relation'] == 'retweeted']
merged_rt = merged_rt.rename(columns={'id tweet retweeted':'id to merge'})
merged_rt = merged_rt.merge(original_tweets_df_normal,on='id to merge',how='left')
merged_rt['text'] = 'RT @'+merged_rt['user retweeted']+': '+merged_rt['whole text']

print(len(merged_rt))
merged_rt.head(2)
# Out:
# 8901
#               id tweet                date  \
# 0  1593298280867323904 2022-11-17 17:41:26
# 1  1593298003141574660 2022-11-17 17:40:20
#
#                                                                                                                                                                                                                                                                                                                                 text  \
# 0  RT @yosoysexmex: Godínez no es tan estúpido después de todo. logró hipnotizar a su jefa para realizar sus deseos más perversos y probar esas enormes y carnosas tetas!  "Hipnotizada" @Karicachonda7 y #RickyMartinez   Link: https://t.co/qrqXqS1bbP  https://t.co/8tX8LnUYU0   #SEXMEX  #FelizMiercoles https://t.co/M0yiyRopuk
# 1                         RT @JorgitoLRA: «Eso no se entiende ¿Quién le dio la orden a usted de nombrar un embajador?», dijo Cabello.  Cabello al presidente uruguayo: no hace falta un embajador de su país  @dcabellor   #PatriaUnidaParaTriunfar #16Noviembre #FelizMiercoles #Qatar2022 #DebatirYRenovar https://t.co/yynsCEatC1
#
#   lang                  app           author            id author  \
# 0   es   Twitter for iPhone       Biscositos           2384230938
# 1   es  Twitter for Android  JoseRafaelbenc2  1041735251633102848
#
#                                                 name  \
# 0                                         Biscositos
# 1  Topógrafo. JOSÉ ꃳEꋊꉔOMO Comunicador Clap Trujillo
#
#                                                                                                                                                 description  \
# 0  Somos Pareja, en busca de diversión, compartir fotos y experiencias etc.....si se da otra cosa porque no?....Cuenta creada y administrada por mi (Mujer)
# 1                                  ✊anti imperialista✊magallanero✊y radicalmente✊chavista, Leales Siempre,Traidores Nunca.🇻🇪🇹🇷🇷🇺🇨🇳 #ComunicadorClapTrujillo
#
#             location          created at author url description urls  \
# 0             México 2014-03-11 21:42:44       None             None
# 1  Valera, Venezuela 2018-09-17 17:06:53       None             None
#
#                                                               profile image url  \
# 0   https://pbs.twimg.com/profile_images/443511399537315840/134wPIe8_normal.png
# 1  https://pbs.twimg.com/profile_images/1396299556439171072/jQWWOH20_normal.jpg
#
#    followers  following  tweets   relation user retweeted  \
# 0        700       2092   40303  retweeted    yosoysexmex
# 1       5717       5705  565271  retweeted     JorgitoLRA
#
#            id to merge  \
# 0  1593000961420627969
# 1  1593079107725963265
#
#                                                                                                                                                                                                                                                                                                          whole text  \
# 0  Godínez no es tan estúpido después de todo. logró hipnotizar a su jefa para realizar sus deseos más perversos y probar esas enormes y carnosas tetas!  "Hipnotizada" @Karicachonda7 y #RickyMartinez   Link: https://t.co/qrqXqS1bbP  https://t.co/8tX8LnUYU0   #SEXMEX  #FelizMiercoles https://t.co/M0yiyRopuk
# 1                        «Eso no se entiende ¿Quién le dio la orden a usted de nombrar un embajador?», dijo Cabello.  Cabello al presidente uruguayo: no hace falta un embajador de su país  @dcabellor   #PatriaUnidaParaTriunfar #16Noviembre #FelizMiercoles #Qatar2022 #DebatirYRenovar https://t.co/yynsCEatC1
#
#                                                                        tweet hashtags  \
# 0                                             [RickyMartinez, SEXMEX, FelizMiercoles]
# 1  [PatriaUnidaParaTriunfar, 16Noviembre, FelizMiercoles, Qatar2022, DebatirYRenovar]
#
#                                                                                                                                                tweet urls  \
# 0  [https://sexmex.xxx/tour/updates/Mesmerized-Kari-Cachonda.html, http://SEXMEX.XXX, https://twitter.com/yosoysexmex/status/1593000961420627969/video/1]
# 1                                                                                     [https://twitter.com/JorgitoLRA/status/1593079107725963265/photo/1]
#
#                 media keys
# 0  [7_1592923712021532672]
# 1  [3_1593079105213325313]

# %% [markdown]
# Los volvemos a unir.

# %%
merged = pd.concat([merged_normal,merged_rt])
merged.head(2)
# Out:
#               id tweet                date  \
# 0  1593295270544134144 2022-11-17 17:29:29
# 1  1593295160485502986 2022-11-17 17:29:02
#
#                                                                                                                                                                             text  \
# 0  #Virgo en el Amor – Miércoles, 16 de noviembre de 2022 #Horóscopo #Amor #Amistad #Zodiaco #Horoscopo2022 #Love https://t.co/KgwdSVF4hx #felizmiércoles #prediccionesamorvirgo
# 1                                                                                                    Qué profesión es más infiel ?  #MiercolesDeGanarSeguidores  #FelizMiercoles
#
#   lang                  app           author            id author  \
# 0   es    Revive Social App  _Horoscopo_Amor   950141474208919554
# 1   es  Twitter for Android   Cata_la_rola23  1590149090482036742
#
#                name  \
# 0    Horóscopo Amor
# 1  Catalina Andrade
#
#                                                                                                                                                       description  \
# 0  ❤️ ❤️ Predicción diaria de los #horóscopos del #AMOR para cada uno de los signos del Zodiaco. Gratis. ✨✨  #Amistad #Parejas #Amor #Sexo #Sexualidad #Love ❤️❤️
# 1                                                                                                     Rola, futbolera, mal pensada, opino de lo que no sé. 🦁🛫🏟️⚽😈
#
#     location          created at                 author url description urls  \
# 0  Estrellas 2018-01-07 23:05:55  [https://t.co/hHWxgGBknR]             None
# 1       None 2022-11-09 01:07:48                       None             None
#
#                                                               profile image url  \
# 0   https://pbs.twimg.com/profile_images/950504674444103683/s8l_MYiX_normal.jpg
# 1  https://pbs.twimg.com/profile_images/1591310513132142592/fy6kmIHZ_normal.jpg
#
#    followers  following  tweets relation user retweeted  \
# 0        106         84   28147    tweet           None
# 1        340        206     200    tweet           None
#
#                                                                                                                                                                       whole text  \
# 0  #Virgo en el Amor – Miércoles, 16 de noviembre de 2022 #Horóscopo #Amor #Amistad #Zodiaco #Horoscopo2022 #Love https://t.co/KgwdSVF4hx #felizmiércoles #prediccionesamorvirgo
# 1                                                                                                    Qué profesión es más infiel ?  #MiercolesDeGanarSeguidores  #FelizMiercoles
#
#                                                                                            tweet hashtags  \
# 0  [Virgo, Horóscopo, Amor, Amistad, Zodiaco, Horoscopo2022, Love, felizmiércoles, prediccionesamorvirgo]
# 1                                                            [MiercolesDeGanarSeguidores, FelizMiercoles]
#
#                                                                                                                               tweet urls  \
# 0  [https://horoscopo-amor.com/virgo-miercoles-16-noviembre-2022/?utm_source=ReviveOldPost&utm_medium=social&utm_campaign=ReviveOldPost]
# 1                                                                                                                                   None
#
#   media keys id to merge
# 0         []         NaN
# 1         []         NaN

# %% [markdown]
# Los volvemos a ordenar por fecha, quitamos la columna de 'whole text' porque ya no nos interesa, volvemos a nombrar la columna con la que hicimos el merge a 'id tweet retweeted', reseteamos el índice y creamos dos columnas de listas vacías para añadir el tipo de audiovisual y el enlace a su imagen. Aunque sea un video en el json aparece una imagen de ejemplo. Si queremos ver el vídeo debemos ir al tweet.

# %%
merged = merged.sort_values(by='date',ascending=False)
merged = merged.drop(['whole text'],axis=1)
merged = merged.rename(columns={'id to merge':'id tweet retweeted'})
merged = merged.reset_index().drop('index',axis=1)
merged['media types'] = np.empty((len(merged), 0)).tolist()
merged['media urls'] = np.empty((len(merged), 0)).tolist()

# %% [markdown]
# Volvemos a loopear, esta vez para conseguir la información de lo audiovisual.

# %%
list_media_flattered = []
i=0
for item in tweets_data:
    if 'media' in item['includes']:
        list_media = item['includes']['media']
        for media in list_media:
            media_key = media['media_key']
            media_type = media['type']
            if media_type == 'photo':
                media_url = media['url']
            elif media_type == 'video' or media_type == 'animated_gif':
                media_url = media['preview_image_url']
                
            list_media_flattered.append([media_key,media_type,media_url])

# %% [markdown]
# Lo metemos en un diccionario.

# %%
media_dict = {}
for list in list_media_flattered:
    media_dict[list[0]] = list[1:]
len(media_dict)
# Out:
# 1355

# %% [markdown]
# Creamos una función para meter en las columnas vacías que creamos antes los tipos y las urls.

# %%
def añadir_media_url(row):
    media_keys = row['media keys']
    if len(media_keys) == 0:
        None
    if len(media_keys) > 0:
        for media in media_keys:
            if media in media_dict:
                row['media types'].append(media_dict[media][0])
                row['media urls'].append(media_dict[media][1])
            else:
                None

# %% [markdown]
# Quitamos los valores NaN.

# %%
merged['media keys'] = merged['media keys'].fillna('None')

# %% [markdown]
# Aplicamos la función

# %%
merged.apply(añadir_media_url,axis=1)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 10386    None
# 10387    None
# 10388    None
# 10389    None
# 10390    None
# Length: 10391, dtype: object

# %% [markdown]
# Extraemos la fecha en la que hemos cogido los tweets y creamos una serie. Esto es simple porque es el mismo valor para todas las líneas del dataframe.

# %%
retrieved_at = tweets_data[0]['__twarc']['retrieved_at']
merged['retrieved at'] = retrieved_at

# %% [markdown]
# Limpiamos también la columna de 'retrieved_at'.

# %%
merged['retrieved at'] = merged['retrieved at'].str.replace('T',' ').apply(lambda x:str(x)).apply(lambda x:x[:-6])
merged['retrieved at'] = merged['retrieved at'].apply(lambda x:dt.strptime(x, '%Y-%m-%d %H:%M:%S'))

# %% [markdown]
# Visualizamos nuestro dataframe final.

# %%
print('Tweets recogidos: ',len(merged))
merged.head(2)
# Out:
# Tweets recogidos:  10391
#               id tweet                date  \
# 0  1593298280867323904 2022-11-17 17:41:26
# 1  1593298003141574660 2022-11-17 17:40:20
#
#                                                                                                                                                                                                                                                                                                                                 text  \
# 0  RT @yosoysexmex: Godínez no es tan estúpido después de todo. logró hipnotizar a su jefa para realizar sus deseos más perversos y probar esas enormes y carnosas tetas!  "Hipnotizada" @Karicachonda7 y #RickyMartinez   Link: https://t.co/qrqXqS1bbP  https://t.co/8tX8LnUYU0   #SEXMEX  #FelizMiercoles https://t.co/M0yiyRopuk
# 1                         RT @JorgitoLRA: «Eso no se entiende ¿Quién le dio la orden a usted de nombrar un embajador?», dijo Cabello.  Cabello al presidente uruguayo: no hace falta un embajador de su país  @dcabellor   #PatriaUnidaParaTriunfar #16Noviembre #FelizMiercoles #Qatar2022 #DebatirYRenovar https://t.co/yynsCEatC1
#
#   lang                  app           author            id author  \
# 0   es   Twitter for iPhone       Biscositos           2384230938
# 1   es  Twitter for Android  JoseRafaelbenc2  1041735251633102848
#
#                                                 name  \
# 0                                         Biscositos
# 1  Topógrafo. JOSÉ ꃳEꋊꉔOMO Comunicador Clap Trujillo
#
#                                                                                                                                                 description  \
# 0  Somos Pareja, en busca de diversión, compartir fotos y experiencias etc.....si se da otra cosa porque no?....Cuenta creada y administrada por mi (Mujer)
# 1                                  ✊anti imperialista✊magallanero✊y radicalmente✊chavista, Leales Siempre,Traidores Nunca.🇻🇪🇹🇷🇷🇺🇨🇳 #ComunicadorClapTrujillo
#
#             location          created at author url description urls  \
# 0             México 2014-03-11 21:42:44       None             None
# 1  Valera, Venezuela 2018-09-17 17:06:53       None             None
#
#                                                               profile image url  \
# 0   https://pbs.twimg.com/profile_images/443511399537315840/134wPIe8_normal.png
# 1  https://pbs.twimg.com/profile_images/1396299556439171072/jQWWOH20_normal.jpg
#
#    followers  following  tweets   relation user retweeted  \
# 0        700       2092   40303  retweeted    yosoysexmex
# 1       5717       5705  565271  retweeted     JorgitoLRA
#
#                                                                        tweet hashtags  \
# 0                                             [RickyMartinez, SEXMEX, FelizMiercoles]
# 1  [PatriaUnidaParaTriunfar, 16Noviembre, FelizMiercoles, Qatar2022, DebatirYRenovar]
#
#                                                                                                                                                tweet urls  \
# 0  [https://sexmex.xxx/tour/updates/Mesmerized-Kari-Cachonda.html, http://SEXMEX.XXX, https://twitter.com/yosoysexmex/status/1593000961420627969/video/1]
# 1                                                                                     [https://twitter.com/JorgitoLRA/status/1593079107725963265/photo/1]
#
#                 media keys   id tweet retweeted media types  \
# 0  [7_1592923712021532672]  1593000961420627969     [video]
# 1  [3_1593079105213325313]  1593079107725963265     [photo]
#
#                                                                                    media urls  \
# 0  [https://pbs.twimg.com/ext_tw_video_thumb/1592923712021532672/pu/img/GB1iTEcOCXU7CVwA.jpg]
# 1                                           [https://pbs.twimg.com/media/FhvBAXVWYAEpdhk.jpg]
#
#          retrieved at
# 0 2022-11-17 17:41:47
# 1 2022-11-17 17:41:47

# %% [markdown]
# Ya podemos guardarlo en un arhivo csv para conservar los datos antes de hacer el análisis con Python.

# %%
merged.to_csv(f'{hashtag}.txt',index=False)
